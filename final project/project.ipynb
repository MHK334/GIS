# %%
import geopandas as gpd

## for data analysis
import pandas as pd

## for pretty charts
import plotly.express as px

# for plotly themes
import plotly.io as pio

## for URL requests
import urllib.request
import requests

## for maps
import folium
from folium import plugins

# %%
df = pd.read_csv('america.csv')

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       262906326  02/02/2023    101                       ASSAULT 3    344
# 1       262898615  02/02/2023    153                          RAPE 3    104
# 2       262939177  02/02/2023    750                RESISTING ARREST    359
# 3       262955266  02/02/2023    792      CRIMINAL POSSESSION WEAPON    118
# 4       262917077  02/02/2023    759  PUBLIC ADMINISTATION,UNCLASS M    359
# ...           ...         ...    ...                             ...    ...
# 16643   265984367  03/31/2023    904     INTOXICATED DRIVING,ALCOHOL    119
# 16644   265938989  03/31/2023    503  CONTROLLED SUBSTANCE,INTENT TO    117
# 16645   265985850  03/31/2023    705              FORGERY,ETC.-MISD.    358
# 16646   265947798  03/31/2023    639         AGGRAVATED HARASSMENT 2    361
# 16647   265983027  03/31/2023    101                       ASSAULT 3    344
#
#                             OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0        ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
# 1                                RAPE  PL 1302501          F           Q
# 2      OFFENSES AGAINST PUBLIC ADMINI  PL 2053000          M           Q
# 3                   DANGEROUS WEAPONS  PL 265031B          F           K
# 4      OFFENSES AGAINST PUBLIC ADMINI  PL 1950500          M           K
# ...                               ...         ...        ...         ...
# 16643    INTOXICATED/IMPAIRED DRIVING  VTL11920E2          F           K
# 16644                 DANGEROUS DRUGS  PL 2201601          F           K
# 16645        OFFENSES INVOLVING FRAUD  PL 1700500          M           B
# 16646   OFF. AGNST PUB ORD SENSBLTY &  PL 2403005          M           Q
# 16647    ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
#
#        ARREST_PRECINCT  ...  X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0                  108  ...      996643     209958  40.742954 -73.955274
# 1                  112  ...     1025401     202586  40.722641 -73.851542
# 2                  113  ...     1048530     192776  40.695570 -73.768191
# 3                   67  ...     1007548     179060  40.658126 -73.916026
# 4                   73  ...     1010719     186857  40.679516 -73.904570
# ...                ...  ...         ...        ...        ...        ...
# 16643               79  ...      999839     190667  40.690000 -73.943784
# 16644               75  ...     1013227     183621  40.670627 -73.895542
# 16645               42  ...     1011092     244692  40.838258 -73.902993
# 16646              106  ...     1028604     187929  40.682389 -73.840079
# 16647               44  ...     1003462     242605  40.832551 -73.930574
#
#                             New Georeferenced Column  Community Districts  \
# 0                       POINT (-73.955274 40.742954)                   53
# 1         POINT (-73.8515418216779 40.7226409964758)                   40
# 2                        POINT (-73.768191 40.69557)                   41
# 3                       POINT (-73.916026 40.658126)                   61
# 4      POINT (-73.90457012340953 40.679516449878804)                   42
# ...                                              ...                  ...
# 16643                       POINT (-73.943784 40.69)                   69
# 16644   POINT (-73.89554183893488 40.67062651008049)                   45
# 16645                   POINT (-73.902993 40.838258)                   34
# 16646                   POINT (-73.840079 40.682389)                   62
# 16647                   POINT (-73.930574 40.832551)                   50
#
#        Borough Boundaries  City Council Districts Police Precincts  Zip Codes
# 0                     3.0                      33               66    16858.0
# 1                     3.0                      28               70    14786.0
# 2                     3.0                       6               71    24669.0
# 3                     2.0                      17               40    17614.0
# 4                     2.0                      37               53    13516.0
# ...                   ...                     ...              ...        ...
# 16643                 2.0                      49               51    18181.0
# 16644                 2.0                      25               47    17214.0
# 16645                 5.0                      42               25    10935.0
# 16646                 3.0                      41               64    24013.0
# 16647                 5.0                      35               27    10930.0
#
# [16648 rows x 24 columns]

# %%
bronx = [40.9584,-73.8087]

# make the map
m = folium.Map(location=bronx, zoom_start=15)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc1a74fa59b1dea951a0a822c337bb03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc1a74fa59b1dea951a0a822c337bb03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc1a74fa59b1dea951a0a822c337bb03 = L.map(
#                 &quot;map_fc1a74fa59b1dea951a0a822c337bb03&quot;,
#                 {
#                     center: [40.9584, -73.8087],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f966ff4e04c423c40a35c2155ee49b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc1a74fa59b1dea951a0a822c337bb03);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16648 entries, 0 to 16647
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                16648 non-null  int64
#  1   ARREST_DATE               16648 non-null  object
#  2   PD_CD                     16648 non-null  int64
#  3   PD_DESC                   16648 non-null  object
#  4   KY_CD                     16648 non-null  int64
#  5   OFNS_DESC                 16648 non-null  object
#  6   LAW_CODE                  16648 non-null  object
#  7   LAW_CAT_CD                16558 non-null  object
#  8   ARREST_BORO               16648 non-null  object
#  9   ARREST_PRECINCT           16648 non-null  int64
#  10  JURISDICTION_CODE         16648 non-null  int64
#  11  AGE_GROUP                 16648 non-null  object
#  12  PERP_SEX                  16648 non-null  object
#  13  PERP_RACE                 16648 non-null  object
#  14  X_COORD_CD                16648 non-null  int64
#  15  Y_COORD_CD                16648 non-null  int64
#  16  Latitude                  16648 non-null  float64
#  17  Longitude                 16648 non-null  float64
#  18  New Georeferenced Column  16648 non-null  object
#  19  Community Districts       16648 non-null  int64
#  20  Borough Boundaries        16647 non-null  float64
#  21  City Council Districts    16648 non-null  int64
#  22  Police Precincts          16648 non-null  int64
#  23  Zip Codes                 16615 non-null  float64
# dtypes: float64(4), int64(10), object(10)
# memory usage: 3.0+ MB

# %%
center_lat = df.latitude.mean()
center_lon = df.longitude.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14828\2272351526.py in ?()
# ----> 1 center_lat = df.latitude.mean()
#       2 center_lon = df.longitude.mean()
#
# c:\Users\matsu\miniconda3\envs\gis\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'latitude'
