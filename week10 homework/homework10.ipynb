# %%
import geopandas as gpd
import pandas as pd
import contextily as ctx
import plotly.express as px
import contextily as cx
import numpy as np
import matplotlib.pyplot as plt

# set font
import matplotlib as mpl


# for PC
mpl.rc('font',family='MS Gothic')

# %%
kagoshimamesh1 = gpd.read_file('data/SDDSWS4028.zip')
kagoshimamesh2 = gpd.read_file('data/SDDSWS4128.zip')
kagoshimamesh3 = gpd.read_file('data/SDDSWS4129.zip')
kagoshimamesh4 = gpd.read_file('data/SDDSWS4229.zip')
kagoshimamesh5 = gpd.read_file('data/SDDSWS4230.zip')
kagoshimamesh6 = gpd.read_file('data/SDDSWS4329.zip')
kagoshimamesh7 = gpd.read_file('data/SDDSWS4429.zip')
kagoshimamesh8 = gpd.read_file('data/SDDSWS4530.zip')
kagoshimamesh9 = gpd.read_file('data/SDDSWS4531.zip')
kagoshimamesh10 = gpd.read_file('data/SDDSWS4629.zip')
kagoshimamesh11 = gpd.read_file('data/SDDSWS4630.zip')
kagoshimamesh12 = gpd.read_file('data/SDDSWS4631.zip')
kagoshimamesh13 = gpd.read_file('data/SDDSWS4729.zip')
kagoshimamesh14 = gpd.read_file('data/SDDSWS4730.zip')
kagoshimamesh15 = gpd.read_file('data/SDDSWS4731.zip')
kagoshimamesh16 = gpd.read_file('data/SDDSWS4830.zip')

# %%
kagoshimamesh = gpd.pd.concat([kagoshimamesh1,kagoshimamesh2,kagoshimamesh3,kagoshimamesh4,kagoshimamesh5,kagoshimamesh6,kagoshimamesh7,kagoshimamesh8,kagoshimamesh9,kagoshimamesh10,kagoshimamesh11,kagoshimamesh12,kagoshimamesh13,kagoshimamesh14,kagoshimamesh15,kagoshimamesh16])

# %%
kagoshimamesh.plot(figsize=(20,20),edgecolor='white',linewidth=0.1,column='MESH1_ID')
# Out:
# <Axes: >

# %%
kagoshimamesh.head()
# Out:
#    KEY_CODE MESH1_ID MESH2_ID MESH3_ID  OBJ_ID  \
# 0  40280000     4028       00       00       1
# 1  40280001     4028       00       01       2
# 2  40280002     4028       00       02       3
# 3  40280003     4028       00       03       4
# 4  40280004     4028       00       04       5
#
#                                             geometry
# 0  POLYGON ((128.01250 26.66667, 128.00000 26.666...
# 1  POLYGON ((128.02500 26.66667, 128.01250 26.666...
# 2  POLYGON ((128.03750 26.66667, 128.02500 26.666...
# 3  POLYGON ((128.05000 26.66667, 128.03750 26.666...
# 4  POLYGON ((128.06250 26.66667, 128.05000 26.666...

# %%
kagoshimadata1= pd.read_csv ('data/tblT001100S4028.zip',encoding='cp932')
kagoshimadata2= pd.read_csv	('data/tblT001100S4128.zip', encoding='cp932')			
kagoshimadata3= pd.read_csv	('data/tblT001100S4129.zip', encoding='cp932')			
kagoshimadata4= pd.read_csv	('data/tblT001100S4229.zip', encoding='cp932')			
kagoshimadata5= pd.read_csv	('data/tblT001100S4230.zip', encoding='cp932')			
kagoshimadata6= pd.read_csv	('data/tblT001100S4329.zip', encoding='cp932')			
kagoshimadata7= pd.read_csv	('data/tblT001100S4429.zip', encoding='cp932')			
kagoshimadata8= pd.read_csv	('data/tblT001100S4530.zip', encoding='cp932')			
kagoshimadata9= pd.read_csv	('data/tblT001100S4531.zip', encoding='cp932')			
kagoshimadata10= pd.read_csv('data/tblT001100S4629.zip', encoding='cp932')			
kagoshimadata11= pd.read_csv('data/tblT001100S4630.zip', encoding='cp932')			
kagoshimadata12= pd.read_csv('data/tblT001100S4631.zip', encoding='cp932')			
kagoshimadata13= pd.read_csv('data/tblT001100S4729.zip', encoding='cp932')			
kagoshimadata14= pd.read_csv('data/tblT001100S4730.zip', encoding='cp932')			
kagoshimadata15= pd.read_csv('data/tblT001100S4731.zip', encoding='cp932')			
kagoshimadata16= pd.read_csv('data/tblT001100S4830.zip', encoding='cp932')

# %%
kagoshimadata4.head()
# Out:
#      KEY_CODE  HTKSYORI     HTKSAKI    GASSAN T001100001 T001100002  \
# 0         NaN       NaN         NaN       NaN    　人口（総数）  　人口（総数）　男
# 1  42290138.0       0.0         NaN       NaN         42         20
# 2  42290152.0       2.0  42290153.0       NaN          2          1
# 3  42290153.0       1.0         NaN  42290152         68         29
# 4  42290230.0       0.0         NaN       NaN         35         19
#
#   T001100003   T001100004  T001100005  T001100006  ...    T001100041  \
# 0  　人口（総数）　女  　０～１４歳人口　総数  　０～１４歳人口　男  　０～１４歳人口　女  ...  　６人世帯数　一般世帯数
# 1         22            3           1           2  ...             0
# 2          1            *           *           *  ...             *
# 3         39           10           4           6  ...             1
# 4         16            0           0           0  ...             0
#
#        T001100042       T001100043     T001100044        T001100045  \
# 0  　７人以上世帯数　一般世帯数  　親族のみの世帯数　一般世帯数  　核家族世帯数　一般世帯数  　核家族以外の世帯数　一般世帯数
# ...

# %%
kagoshimadata1 	=kagoshimadata1	[1:]
kagoshimadata2	=kagoshimadata2	[1:]
kagoshimadata3	=kagoshimadata3	[1:]
kagoshimadata4	=kagoshimadata4	[1:]
kagoshimadata5	=kagoshimadata5	[1:]
kagoshimadata6	=kagoshimadata6	[1:]
kagoshimadata7	=kagoshimadata7	[1:]
kagoshimadata8	=kagoshimadata8	[1:]
kagoshimadata9	=kagoshimadata9	[1:]
kagoshimadata10	=kagoshimadata10[1:]
kagoshimadata11	=kagoshimadata11	[1:]
kagoshimadata12	=kagoshimadata12	[1:]
kagoshimadata13	=kagoshimadata13	[1:]
kagoshimadata14	=kagoshimadata14	[1:]
kagoshimadata15	=kagoshimadata15	[1:]
kagoshimadata16	=kagoshimadata16	[1:]

# %%
kagoshimadata1	=	kagoshimadata1	.	replace('*',np.nan)
kagoshimadata2	=	kagoshimadata2	.	replace('*',np.nan)
kagoshimadata3	=	kagoshimadata3	.	replace('*',np.nan)
kagoshimadata4	=	kagoshimadata4	.	replace('*',np.nan)
kagoshimadata5	=	kagoshimadata5	.	replace('*',np.nan)
kagoshimadata6	=	kagoshimadata6	.	replace('*',np.nan)
kagoshimadata7	=	kagoshimadata7	.	replace('*',np.nan)
kagoshimadata8	=	kagoshimadata8	.	replace('*',np.nan)
kagoshimadata9	=	kagoshimadata9	.	replace('*',np.nan)
kagoshimadata10	=	kagoshimadata10	.	replace('*',np.nan)
kagoshimadata11	=	kagoshimadata11	.	replace('*',np.nan)
kagoshimadata12	=	kagoshimadata12	.	replace('*',np.nan)
kagoshimadata13	=	kagoshimadata13	.	replace('*',np.nan)
kagoshimadata14	=	kagoshimadata14	.	replace('*',np.nan)
kagoshimadata15	=	kagoshimadata15	.	replace('*',np.nan)
kagoshimadata16	=	kagoshimadata16	.	replace('*',np.nan)

# %%
kagoshimadata1
# Out:
#        KEY_CODE  HTKSYORI  HTKSAKI GASSAN T001100001 T001100002 T001100003  \
# 1    40280000.0       0.0      NaN    NaN        204         95        109
# 2    40280001.0       0.0      NaN    NaN        301        153        148
# 3    40280008.0       0.0      NaN    NaN        421        219        202
# 4    40280009.0       0.0      NaN    NaN        141         74         67
# 5    40280010.0       0.0      NaN    NaN         48         27         21
# ..          ...       ...      ...    ...        ...        ...        ...
# 112  40284375.0       0.0      NaN    NaN         51         20         31
# 113  40284384.0       0.0      NaN    NaN         15          6          9
# 114  40287494.0       0.0      NaN    NaN        159         80         79
# 115  40287495.0       0.0      NaN    NaN        408        200        208
# 116  40287496.0       0.0      NaN    NaN        115         54         61
#
# ...

# %%
kagoshimadata = pd.concat([kagoshimadata1,	kagoshimadata2,	kagoshimadata3,	kagoshimadata4,	kagoshimadata5,	kagoshimadata6,	kagoshimadata7,	kagoshimadata8,	kagoshimadata9,	kagoshimadata10,	kagoshimadata11,	kagoshimadata12,	kagoshimadata13,	kagoshimadata14,	kagoshimadata15,	kagoshimadata16,])

# %%
kagoshimadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9495 entries, 1 to 2897
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    9495 non-null   float64
#  1   HTKSYORI    9495 non-null   float64
#  2   HTKSAKI     1641 non-null   float64
#  3   GASSAN      1284 non-null   object
#  4   T001100001  9495 non-null   object
#  5   T001100002  9495 non-null   object
#  6   T001100003  9495 non-null   object
#  7   T001100004  7854 non-null   object
#  8   T001100005  7854 non-null   object
#  9   T001100006  7854 non-null   object
#  10  T001100007  7854 non-null   object
#  11  T001100008  7854 non-null   object
#  12  T001100009  7854 non-null   object
#  13  T001100010  7854 non-null   object
#  14  T001100011  7854 non-null   object
#  15  T001100012  7854 non-null   object
#  16  T001100013  7854 non-null   object
#  17  T001100014  7854 non-null   object
#  18  T001100015  7854 non-null   object
# ...

# %%
kagoshimadata.columns
# Out:
# Index(['KEY_CODE', 'HTKSYORI', 'HTKSAKI', 'GASSAN', 'T001100001', 'T001100002',
#        'T001100003', 'T001100004', 'T001100005', 'T001100006', 'T001100007',
#        'T001100008', 'T001100009', 'T001100010', 'T001100011', 'T001100012',
#        'T001100013', 'T001100014', 'T001100015', 'T001100016', 'T001100017',
#        'T001100018', 'T001100019', 'T001100020', 'T001100021', 'T001100022',
#        'T001100023', 'T001100024', 'T001100025', 'T001100026', 'T001100027',
#        'T001100028', 'T001100029', 'T001100030', 'T001100031', 'T001100032',
#        'T001100033', 'T001100034', 'T001100035', 'T001100036', 'T001100037',
#        'T001100038', 'T001100039', 'T001100040', 'T001100041', 'T001100042',
#        'T001100043', 'T001100044', 'T001100045', 'T001100046', 'T001100047',
#        'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
kagoshimadata.columns[4:]
# Out:
# Index(['T001100001', 'T001100002', 'T001100003', 'T001100004', 'T001100005',
#        'T001100006', 'T001100007', 'T001100008', 'T001100009', 'T001100010',
#        'T001100011', 'T001100012', 'T001100013', 'T001100014', 'T001100015',
#        'T001100016', 'T001100017', 'T001100018', 'T001100019', 'T001100020',
#        'T001100021', 'T001100022', 'T001100023', 'T001100024', 'T001100025',
#        'T001100026', 'T001100027', 'T001100028', 'T001100029', 'T001100030',
#        'T001100031', 'T001100032', 'T001100033', 'T001100034', 'T001100035',
#        'T001100036', 'T001100037', 'T001100038', 'T001100039', 'T001100040',
#        'T001100041', 'T001100042', 'T001100043', 'T001100044', 'T001100045',
#        'T001100046', 'T001100047', 'T001100048', 'T001100049', 'T001100050'],
#       dtype='object')

# %%
kagoshimadata[kagoshimadata.columns[4:]]
# Out:
#      T001100001 T001100002 T001100003 T001100004 T001100005 T001100006  \
# 1           204         95        109         20         11          9
# 2           301        153        148         29         12         17
# 3           421        219        202         50         29         21
# 4           141         74         67          4          2          2
# 5            48         27         21          5          1          4
# ...         ...        ...        ...        ...        ...        ...
# 2893          8          4          4        NaN        NaN        NaN
# 2894         86         41         45         12          6          6
# 2895        113         55         58         12          5          7
# 2896        114         62         52          8          6          2
# 2897         58         23         35          6          0          6
#
#      T001100007 T001100008 T001100009 T001100010  ... T001100041 T001100042  \
# ...

# %%
kagoshimadata[kagoshimadata.columns[4:]].astype(float)
# Out:
#       T001100001  T001100002  T001100003  T001100004  T001100005  T001100006  \
# 1          204.0        95.0       109.0        20.0        11.0         9.0
# 2          301.0       153.0       148.0        29.0        12.0        17.0
# 3          421.0       219.0       202.0        50.0        29.0        21.0
# 4          141.0        74.0        67.0         4.0         2.0         2.0
# 5           48.0        27.0        21.0         5.0         1.0         4.0
# ...          ...         ...         ...         ...         ...         ...
# 2893         8.0         4.0         4.0         NaN         NaN         NaN
# 2894        86.0        41.0        45.0        12.0         6.0         6.0
# 2895       113.0        55.0        58.0        12.0         5.0         7.0
# 2896       114.0        62.0        52.0         8.0         6.0         2.0
# 2897        58.0        23.0        35.0         6.0         0.0         6.0
#
# ...

# %%
kagoshimadata[kagoshimadata.columns[4:]]=kagoshimadata[kagoshimadata.columns[4:]].astype(float)

# %%
kagoshimadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9495 entries, 1 to 2897
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KEY_CODE    9495 non-null   float64
#  1   HTKSYORI    9495 non-null   float64
#  2   HTKSAKI     1641 non-null   float64
#  3   GASSAN      1284 non-null   object
#  4   T001100001  9495 non-null   float64
#  5   T001100002  9495 non-null   float64
#  6   T001100003  9495 non-null   float64
#  7   T001100004  7854 non-null   float64
#  8   T001100005  7854 non-null   float64
#  9   T001100006  7854 non-null   float64
#  10  T001100007  7854 non-null   float64
#  11  T001100008  7854 non-null   float64
#  12  T001100009  7854 non-null   float64
#  13  T001100010  7854 non-null   float64
#  14  T001100011  7854 non-null   float64
#  15  T001100012  7854 non-null   float64
#  16  T001100013  7854 non-null   float64
#  17  T001100014  7854 non-null   float64
# ...

# %%
kagoshimamesh['KEY_CODE']=kagoshimamesh['KEY_CODE'].astype(float)

# %%
kagoshimamesh = kagoshimamesh.merge(kagoshimadata, on='KEY_CODE')

# %%
kagoshimamesh.sample(5)
# Out:
#         KEY_CODE MESH1_ID MESH2_ID MESH3_ID  OBJ_ID  \
# 4170  47305777.0     4730       57       77    4278
# 8492  48305139.0     4830       51       39    4040
# 7339  48302042.0     4830       20       42    1543
# 8334  48304512.0     4830       45       12    3613
# 2764  47302706.0     4730       27       06    2207
#
#                                                geometry  HTKSYORI     HTKSAKI  \
# 4170  POLYGON ((130.97500 31.80833, 130.96250 31.808...       2.0  47305778.0
# 8492  POLYGON ((130.25000 32.44167, 130.23750 32.441...       0.0         NaN
# 7339  POLYGON ((130.03750 32.20000, 130.02500 32.200...       0.0         NaN
# 8334  POLYGON ((130.66250 32.34167, 130.65000 32.341...       2.0  48304521.0
# 2764  POLYGON ((130.96250 31.50000, 130.95000 31.500...       0.0         NaN
#
#      GASSAN  T001100001  ...  T001100041  T001100042  T001100043  T001100044  \
# 4170    NaN         4.0  ...         NaN         NaN         NaN         NaN
# ...

# %%
kagoshimamesh = kagoshimamesh.to_crs(3857)

# %%
kagoshimamesh.plot(column='T001100030')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,10))

kagoshimamesh.plot(ax=ax,
         column='T001100004',
         legend=True,
         cmap='autumn_r',
         edgecolor='black',
         linewidth=0.1,
         alpha=0.8,
        #  vmax=3000,
         legend_kwds={'label': "０～１４歳人口　総数人",'shrink': 0.6, 'orientation': "horizontal", 'pad': 0.01}
)

# マップの範囲を chibamesh の境界に設定
ax.set_xlim(kagoshimamesh.total_bounds[0], kagoshimamesh.total_bounds[2])
ax.set_ylim(kagoshimamesh.total_bounds[1], kagoshimamesh.total_bounds[3])

# 軸を非表示にする
ax.axis('off')

# タイトル
ax.set_title('０～１４歳人口　総数人',fontsize=24,pad=20);

# ベースマップを追加
cx.add_basemap(ax,source='https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png')

# %%
kagoshimamesh['Percent0_14'] = kagoshimamesh['T001100004'] / kagoshimamesh['T001100001']*100

# コロプレスマップをプロットする
fig, ax = plt.subplots(figsize=(10, 10))

kagoshimamesh.plot(ax=ax,
               column='Percent0_14',
               legend=True,
               cmap='RdYlGn_r',
               edgecolor='black',
               linewidth=0.1,
               alpha=0.8,
               vmax=20,
               legend_kwds={'label': '０～１４歳人口　総数人％', 'shrink': 0.6, 'orientation': 'horizontal', 'pad': 0.01}
              )

# マップの範囲を chibamesh の境界に設定する
ax.set_xlim(kagoshimamesh.total_bounds[0], kagoshimamesh.total_bounds[2])
ax.set_ylim(kagoshimamesh.total_bounds[1], kagoshimamesh.total_bounds[3])

# 軸を非表示にする
ax.axis('off')

# タイトルを設定する
ax.set_title('０～１４歳の子供はどこにいるの？', fontsize=24, pad=20)

# ベースマップを追加する
cx.add_basemap(ax, source='https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png')

# %%
kagoshimamesh['Percent75over'] = kagoshimamesh['T001100022'] / kagoshimamesh['T001100001']*100

# コロプレスマップをプロットする
fig, ax = plt.subplots(figsize=(10, 10))

kagoshimamesh.plot(ax=ax,
               column='Percent75over',
               legend=True,
               cmap='RdYlGn_r',
               edgecolor='black',
               linewidth=0.1,
               alpha=0.8,
               vmax=30,
               legend_kwds={'label': '７５歳以上人口　総数', 'shrink': 0.6, 'orientation': 'horizontal', 'pad': 0.01}
              )

# マップの範囲を chibamesh の境界に設定する
ax.set_xlim(kagoshimamesh.total_bounds[0], kagoshimamesh.total_bounds[2])
ax.set_ylim(kagoshimamesh.total_bounds[1], kagoshimamesh.total_bounds[3])

# 軸を非表示にする
ax.axis('off')

# タイトルを設定する
ax.set_title('高齢者はどこにいるの？', fontsize=24, pad=20)

# ベースマップを追加する
cx.add_basemap(ax, source='https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png')

# %% [markdown]
# 高齢者のほうが若者よりも明らかに多いということがこの図を見てよくわかった。今までで一番大変な作業だった
