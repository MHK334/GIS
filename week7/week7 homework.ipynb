# %%
import geopandas as gpd
import pandas as pd

# %%
hiroshima_ku = gpd.read_file('hiroshima_ku.geojson')

# %%
hiroshima_ku.plot()
# Out:
# <Axes: >

# %%
hiroshima_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   699 non-null    object
#  1   N03_002   0 non-null      object
#  2   N03_003   118 non-null    object
#  3   N03_004   699 non-null    object
#  4   N03_007   699 non-null    object
#  5   geometry  699 non-null    geometry
# dtypes: geometry(1), object(5)
# memory usage: 32.9+ KB

# %%
hiroshima_pop = pd.read_csv('hiroshima.csv')

# %%
hiroshima_pop.head()
# Out:
#       KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN    人口総数  \
# 0          NaN     NaN      NaN    NaN       NaN      NaN     NaN     NaN
# 1      34101.0     1.0    広島市中区    NaN       0.0      NaN     NaN  142699
# 2  341010430.0     2.0    広島市中区   白島北町       0.0      NaN     NaN    1969
# 3  341010440.0     2.0    広島市中区   白島中町       0.0      NaN     NaN    1210
# 4  341010450.0     2.0    広島市中区  白島九軒町       0.0      NaN     NaN    1408
#
#        男      女   世帯総数
# 0    NaN    NaN    NaN
# 1  67660  75039  81602
# 2    837   1132   1160
# 3    565    645    660
# 4    642    766    797

# %%
hiroshima_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4977 entries, 0 to 4976
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  4976 non-null   float64
#  1   HYOSYO    4976 non-null   float64
#  2   CITYNAME  4976 non-null   object
#  3   NAME      4929 non-null   object
#  4   HTKSYORI  4976 non-null   float64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      4976 non-null   object
#  8   男         4976 non-null   object
#  9   女         4976 non-null   object
#  10  世帯総数      4976 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 427.8+ KB

# %%
hiroshima_ku.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
hiroshima_ku
# Out:
#     N03_001 N03_002 N03_003 N03_004 KEY_CODE  \
# 0       広島県    None     広島市   広島市中区    34101
# 1       広島県    None     広島市   広島市東区    34102
# 2       広島県    None     広島市   広島市南区    34103
# 3       広島県    None     広島市   広島市南区    34103
# 4       広島県    None     広島市   広島市南区    34103
# ..      ...     ...     ...     ...      ...
# 694     広島県    None     豊田郡   大崎上島町    34431
# 695     広島県    None     豊田郡   大崎上島町    34431
# 696     広島県    None     豊田郡   大崎上島町    34431
# 697     広島県    None     世羅郡     世羅町    34462
# 698     広島県    None     神石郡   神石高原町    34545
#
#                                               geometry
# 0    POLYGON ((132.42048 34.35925, 132.42289 34.362...
# 1    POLYGON ((132.53831 34.46203, 132.53866 34.462...
# 2    POLYGON ((132.40288 34.31495, 132.40286 34.314...
# 3    POLYGON ((132.46303 34.31688, 132.46313 34.316...
# 4    POLYGON ((132.40557 34.31795, 132.40558 34.317...
# ..                                                 ...
# 694  POLYGON ((132.94608 34.29847, 132.94603 34.298...
# 695  POLYGON ((132.90339 34.29838, 132.90359 34.298...
# 696  POLYGON ((132.91567 34.30019, 132.91563 34.300...
# 697  POLYGON ((132.89737 34.68375, 132.89765 34.683...
# 698  POLYGON ((133.21583 34.86135, 133.21575 34.861...
#
# [699 rows x 6 columns]

# %%
hiroshima_ku['KEY_CODE'] = hiroshima_ku['KEY_CODE'].astype(int)

# %%
hiroshima_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   699 non-null    object
#  1   N03_002   0 non-null      object
#  2   N03_003   118 non-null    object
#  3   N03_004   699 non-null    object
#  4   KEY_CODE  699 non-null    int32
#  5   geometry  699 non-null    geometry
# dtypes: geometry(1), int32(1), object(4)
# memory usage: 30.2+ KB

# %%
hiroshima_ku_pop = hiroshima_ku.merge(hiroshima_pop,on='KEY_CODE')
# Out:
# c:\Users\matsu\miniconda3\envs\gis\Lib\site-packages\geopandas\geodataframe.py:1574: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   result = DataFrame.merge(self, *args, **kwargs)

# %%
hiroshima_ku_pop
# Out:
#     N03_001 N03_002 N03_003 N03_004  KEY_CODE  \
# 0       広島県    None     広島市   広島市中区     34101
# 1       広島県    None     広島市   広島市東区     34102
# 2       広島県    None     広島市   広島市南区     34103
# 3       広島県    None     広島市   広島市南区     34103
# 4       広島県    None     広島市   広島市南区     34103
# ..      ...     ...     ...     ...       ...
# 694     広島県    None     豊田郡   大崎上島町     34431
# 695     広島県    None     豊田郡   大崎上島町     34431
# 696     広島県    None     豊田郡   大崎上島町     34431
# 697     広島県    None     世羅郡     世羅町     34462
# 698     広島県    None     神石郡   神石高原町     34545
#
#                                               geometry  HYOSYO CITYNAME NAME  \
# 0    POLYGON ((132.42048 34.35925, 132.42289 34.362...     1.0    広島市中区  NaN
# 1    POLYGON ((132.53831 34.46203, 132.53866 34.462...     1.0    広島市東区  NaN
# 2    POLYGON ((132.40288 34.31495, 132.40286 34.314...     1.0    広島市南区  NaN
# 3    POLYGON ((132.46303 34.31688, 132.46313 34.316...     1.0    広島市南区  NaN
# 4    POLYGON ((132.40557 34.31795, 132.40558 34.317...     1.0    広島市南区  NaN
# ..                                                 ...     ...      ...  ...
# 694  POLYGON ((132.94608 34.29847, 132.94603 34.298...     1.0    大崎上島町  NaN
# 695  POLYGON ((132.90339 34.29838, 132.90359 34.298...     1.0    大崎上島町  NaN
# 696  POLYGON ((132.91567 34.30019, 132.91563 34.300...     1.0    大崎上島町  NaN
# 697  POLYGON ((132.89737 34.68375, 132.89765 34.683...     1.0      世羅町  NaN
# 698  POLYGON ((133.21583 34.86135, 133.21575 34.861...     1.0    神石高原町  NaN
#
#      HTKSYORI  HTKSAKI  GASSAN    人口総数      男      女   世帯総数
# 0         0.0      NaN     NaN  142699  67660  75039  81602
# 1         0.0      NaN     NaN  119353  56872  62481  53056
# 2         0.0      NaN     NaN  145805  71544  74261  72206
# 3         0.0      NaN     NaN  145805  71544  74261  72206
# 4         0.0      NaN     NaN  145805  71544  74261  72206
# ..        ...      ...     ...     ...    ...    ...    ...
# 694       0.0      NaN     NaN    7158   3663   3495   3437
# 695       0.0      NaN     NaN    7158   3663   3495   3437
# 696       0.0      NaN     NaN    7158   3663   3495   3437
# 697       0.0      NaN     NaN   15125   7156   7969   6085
# 698       0.0      NaN     NaN    8250   3932   4318   3339
#
# [699 rows x 16 columns]

# %%
hiroshima_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   699 non-null    object
#  1   N03_002   0 non-null      object
#  2   N03_003   118 non-null    object
#  3   N03_004   699 non-null    object
#  4   KEY_CODE  699 non-null    int32
#  5   geometry  699 non-null    geometry
#  6   HYOSYO    699 non-null    float64
#  7   CITYNAME  699 non-null    object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  699 non-null    float64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      699 non-null    object
#  13  男         699 non-null    object
#  14  女         699 non-null    object
#  15  世帯総数      699 non-null    object
# dtypes: float64(4), geometry(1), int32(1), object(10)
# memory usage: 84.8+ KB

# %%
hiroshima_ku_pop['人口総数'] = hiroshima_ku_pop['人口総数'].astype(int)

# %%
hiroshima_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   699 non-null    object
#  1   N03_002   0 non-null      object
#  2   N03_003   118 non-null    object
#  3   N03_004   699 non-null    object
#  4   KEY_CODE  699 non-null    int32
#  5   geometry  699 non-null    geometry
#  6   HYOSYO    699 non-null    float64
#  7   CITYNAME  699 non-null    object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  699 non-null    float64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      699 non-null    int32
#  13  男         699 non-null    object
#  14  女         699 non-null    object
#  15  世帯総数      699 non-null    object
# dtypes: float64(4), geometry(1), int32(2), object(9)
# memory usage: 82.0+ KB

# %%
hiroshima_ku_pop.plot(column='人口総数',legend=True)
# Out:
# <Axes: >

# %%
hiroshima_ku_pop.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True,
                  cmap='RdYlGn_r')
# Out:
# <Axes: >
